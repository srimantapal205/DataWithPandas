# %% [markdown]
# # Pandas DataFrames

# %% [markdown]
# A pandas DataFrame is a 2 dimensional data structure , like a 2 dimensional array, or a able with rows and columns.

# %% [markdown]
# ### Create a simple Pandas DataFrame:

# %%
import pandas as pd
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

# Load data into a DataFrame object:
df = pd.DataFrame(data)
print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %% [markdown]
# ## Locate Row
# Pandas use the loc attribute to return one or more specified row(s)

# %%
# refer to the row index:
print(df.loc[0])
# Out:
# calories    420
# duration     50
# Name: 0, dtype: int64

# %%
#use a list indexer to refer to multiple rows:
print(df.loc[[0,1]]) #When using [], the result is a Pandas DataFrame.
# Out:
#    calories  duration
# 0       420        50
# 1       380        40

# %% [markdown]
# ### Named Indexes
#
# With the index argument, you can name your own indexes.

# %%
df_index = pd.DataFrame(data, index=["day_1", "day_2","day_3" ])
print(df_index)
# Out:
#        calories  duration
# day_1       420        50
# day_2       380        40
# day_3       390        45

# %% [markdown]
# ### Locate Named Indexes
#
# The named index in the loc attributes to retrn the specified rows(s)

# %%
#Return "day2":
#refer to the named index:

print(df_index.loc["day_2"])
# Out:
# calories    380
# duration     40
# Name: day_2, dtype: int64

# %% [markdown]
# ### Load Files Into a DataFrame

# %%
df = pd.read_csv('../data/data.csv')
print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]
